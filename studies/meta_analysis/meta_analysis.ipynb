# %%
# Compare different source amplitude withe exp in PT scenario (coarse resolution)
import pygkyl
import matplotlib.pyplot as plt
import numpy as np

f_ne_exp = 'ne_exp_PT.dat'
f_Te_exp = 'Te_exp_PT.dat'
Lx = 0.23180811173593874
data = np.loadtxt(f_ne_exp, delimiter=',') 
ne_exp_x = data[:,0]/Lx+1
ne_exp_y = data[:,1]
data = np.loadtxt(f_Te_exp, delimiter=',') 
Te_exp_x = data[:,0]/Lx+1
Te_exp_y = data[:,1]

f_ne_p5_sim = 'ne_p5_PT.dat'
f_Te_p5_sim = 'Te_p5_PT.dat'
data = np.loadtxt(f_ne_p5_sim, delimiter=',')
ne_p5_sim_x = data[:,0]
ne_p5_sim_y = data[:,1]*1e19
data = np.loadtxt(f_Te_p5_sim, delimiter=',')
Te_p5_sim_x = data[:,0]
Te_p5_sim_y = data[:,1]


f_PT_x1 ='fig_profiles_PT_src1x_24x12x12x10x6.pkl'
f_PT_x2 ='fig_profiles_PT_src2x_24x12x12x10x6.pkl'
f_PT_x3 ='fig_profiles_PT_src3x_24x12x12x10x6.pkl'



# Plot ne
plt.figure(1)
fieldname = 'ne'
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x1,fieldname)
plt.plot(x, y, label='24x12 src x1')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x2,fieldname)
plt.plot(x, y, label='24x12 src x2')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x3,fieldname)
plt.plot(x, y, label='24x12 src x3')
plt.plot(ne_p5_sim_x, ne_p5_sim_y, '--', label='48x32 src x1')
plt.plot(ne_exp_x, ne_exp_y, 'ok', label='exp')
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(fieldname)
plt.legend()
plt.show()

fieldname = 'Te'
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x1,fieldname)
plt.plot(x, y, label='24x12 src x1')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x2,fieldname)
plt.plot(x, y, label='24x12 src x2')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x3,fieldname)
plt.plot(x, y, label='24x12 src x3')
plt.plot(Te_p5_sim_x, Te_p5_sim_y, '--', label='48x32 src x1')
plt.plot(ne_exp_x, Te_exp_y, 'ok', label='exp')
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(fieldname)
plt.legend()
plt.show()

# %%
# Compare different source amplitude withe exp in PT scenario (coarse resolution)
import pygkyl
import matplotlib.pyplot as plt
import numpy as np

f_PT_x1 ='fig_profiles_PT_src1x_24x12x12x10x6.pkl'
f_PT_x2 ='fig_profiles_PT_src2x_24x12x12x10x6.pkl'
f_PT_x3 ='fig_profiles_PT_src3x_24x12x12x10x6.pkl'



# Plot ne
plt.figure(1)
fieldname = 'ni'
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x1,fieldname)
plt.plot(x, y, label='24x12 src x1')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x2,fieldname)
plt.plot(x, y, label='24x12 src x2')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x3,fieldname)
plt.plot(x, y, label='24x12 src x3')
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(fieldname)
plt.legend()
plt.show()

fieldname = 'Ti'
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x1,fieldname)
plt.plot(x, y, label='24x12 src x1')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x2,fieldname)
plt.plot(x, y, label='24x12 src x2')
x,y,xlabel,ylabel,vlabel = pygkyl.fig_tools.figdatadict_get_data(f_PT_x3,fieldname)
plt.plot(x, y, label='24x12 src x3')
plt.xlabel(xlabel)
plt.ylabel(ylabel)
plt.title(fieldname)
plt.legend()
plt.show()

# %%
import pygkyl
# fNT ='fig_profiles_NT_glb1.5_24x12x12x10x6';
fNT ='fig_profiles_NT_src1.0_24x12x12x10x6';
fPT ='fig_profiles_PT_src1.5_24x12x12x10x6';
#fNT ='/pscratch/sd/a/ah1032/gkyl_clopen_fix_phase5.1/p5_NT_trueq_300eV_src/fig_profiles';
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=0,lnums=[[0],[1]])
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=2,lnums=[[0],[1]])
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=6,lnums=[[0],[1]])
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=7,lnums=[[0],[1]])
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=0,lnums=[[0]])
pygkyl.fig_tools.compare_figouts(fNT,fPT,name1='NT',name2='PT',plot_idx=2,lnums=[[0]])

# %%
Lx = 0.23180811173593874
ne_NT_exp = {}
ne_NT_exp['label'] =r'$NT exp$';
data = np.loadtxt('ne_exp_NT.txt', delimiter=',') 
ne_NT_exp['xdata'] = data[:,0]/Lx+1;
ne_NT_exp['ydata'] = data[:,1];

ne_NT_sim = {}
ne_NT_sim['label'] =r'$NT sim$';
data = np.loadtxt('ne_p5_NT.txt', delimiter=',') 
ne_NT_sim['xdata'] = data[:,0];
ne_NT_sim['ydata'] = data[:,1]*1e19;

ne_PT_exp = {}
ne_PT_exp['label'] =r'$PT exp$';
data = np.loadtxt('ne_exp_PT.txt', delimiter=',') 
ne_PT_exp['xdata'] = data[:,0]/Lx+1;
ne_PT_exp['ydata'] = data[:,1];

ne_PT_sim = {}
ne_PT_sim['label'] =r'$PT sim$';
data = np.loadtxt('ne_p5_PT.txt', delimiter=',') 
ne_PT_sim['xdata'] = data[:,0];
ne_PT_sim['ydata'] = data[:,1]*1e19;

plt.plot(ne_NT_sim['xdata'],ne_NT_sim['ydata'],'-b',label=ne_NT_sim['label'])
plt.plot(ne_PT_sim['xdata'],ne_PT_sim['ydata'],'-r',label=ne_PT_sim['label'])
plt.plot(ne_NT_exp['xdata'],ne_NT_exp['ydata'],'ob',label=ne_NT_exp['label'])
plt.plot(ne_PT_exp['xdata'],ne_PT_exp['ydata'],'or',label=ne_PT_exp['label'])
plt.legend()
plt.ylabel(r'$n_e$ [m$^{-3}$]')
plt.xlabel('r/a')
plt.show()

Te_NT_exp = {}
Te_NT_exp['label'] =r'NT exp';
data = np.loadtxt('Te_exp_NT.txt', delimiter=',') 
Te_NT_exp['xdata'] = data[:,0]/Lx+1;
Te_NT_exp['ydata'] = data[:,1];

Te_NT_sim = {}
Te_NT_sim['label'] =r'NT sim';
data = np.loadtxt('Te_p5_NT.txt', delimiter=',') 
Te_NT_sim['xdata'] = data[:,0];
Te_NT_sim['ydata'] = data[:,1];

Te_PT_exp = {}
Te_PT_exp['label'] =r'PT exp';
data = np.loadtxt('Te_exp_PT.txt', delimiter=',') 
Te_PT_exp['xdata'] = data[:,0]/Lx+1;
Te_PT_exp['ydata'] = data[:,1];

Te_PT_sim = {}
Te_PT_sim['label'] =r'PT sim';
data = np.loadtxt('Te_p5_PT.txt', delimiter=',') 
Te_PT_sim['xdata'] = data[:,0];
Te_PT_sim['ydata'] = data[:,1];

plt.plot(Te_NT_sim['xdata'],Te_NT_sim['ydata'],'-b',label=Te_NT_sim['label'])
plt.plot(Te_PT_sim['xdata'],Te_PT_sim['ydata'],'-r',label=Te_PT_sim['label'])
plt.plot(Te_NT_exp['xdata'],Te_NT_exp['ydata'],'ob',label=Te_NT_exp['label'])
plt.plot(Te_PT_exp['xdata'],Te_PT_exp['ydata'],'or',label=Te_PT_exp['label'])
plt.legend()
plt.ylabel(r'$T_e$ [eV]')
plt.xlabel('r/a')
plt.show()

# %%
fPT ='/pscratch/sd/a/ah1032/gkyl_clopen_fix_phase5.1/p5_PT_trueq/ExB_radial_PT';
fNT ='/pscratch/sd/a/ah1032/gkyl_clopen_fix_phase5.1/p5_NT_trueq/ExB_radial_NT';
fdict_PT = fig_utils.load_figout(fPT)
fdict_NT = fig_utils.load_figout(fNT)

fig,ax = plt.subplots(1,1,figsize=(6,4))
subfig_idx = 1
curve = fdict_PT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'r',label='PT')
curve = fdict_NT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'b',label='NT')
ax.set_xlim([0.9,1.2])
ax.set_ylim([-1,1])
ax.set_xlabel(fdict_PT[subfig_idx]['xlabel'])
ax.set_ylabel(fdict_PT[subfig_idx]['ylabel'])
plt.legend()
plt.tight_layout()
plt.show()

fig,ax = plt.subplots(1,1,figsize=(6,4))
subfig_idx = 2
curve = fdict_PT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'r',label='PT')
curve = fdict_NT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'b',label='NT')
ax.set_xlim([0.9,1.2])
ax.set_ylim([-2e-5,2e-5])
ax.set_xlabel(fdict_PT[subfig_idx]['xlabel'])
ax.set_ylabel(fdict_PT[subfig_idx]['ylabel'])
plt.legend()
plt.tight_layout()
plt.show()

fig,ax = plt.subplots(1,1,figsize=(6,4))
subfig_idx = 3
curve = fdict_PT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'r',label='PT')
curve = fdict_NT[subfig_idx]['curves'][0]
ax.plot(curve['xdata'],curve['ydata'],'b',label='NT')
ax.set_xlim([0.9,1.2])
ax.set_ylim([-4e-3,4e-3])
ax.set_xlabel(fdict_PT[subfig_idx]['xlabel'])
ax.set_ylabel(fdict_PT[subfig_idx]['ylabel'])
plt.legend()
plt.tight_layout()
plt.show()
